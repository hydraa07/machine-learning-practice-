# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("F:\Jupyter Notebook\python programe\DS  first\ML\placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
# x = df['cgpa']
# y = df['package']

# %%
print(x)
print(y)
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]  # this place use the slicing

# %%
print(x)
print(y)
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (200, 1)
# (200,)

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.3, random_state=1234)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
y_test.shape
# Out:
# (140, 1)
# (60, 1)
# (140,)
# (60,)

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
plt.scatter(x_test,y_test)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)
y_predict
# Out:
# array([3.10014146, 2.67665788, 3.60946632, 3.91277213, 4.21607795,
#        3.30043776, 3.48928855, 2.83689491, 3.0486367 , 3.41489278,
#        2.84261766, 2.89984517, 1.90980921, 2.61943036, 2.93990443,
#        2.96851819, 2.35618381, 3.06580496, 2.89412242, 3.32332876,
#        3.06008221, 2.8140039 , 3.61518907, 4.27330546, 3.4950113 ,
#        2.075769  , 3.7296441 , 2.20166953, 3.16881448, 4.34197847,
#        2.82544941, 1.58933515, 2.5793711 , 2.31612455, 1.89264096,
#        2.13871926, 2.85978591, 3.14020072, 2.5335891 , 2.93418168,
#        2.44774783, 2.95707268, 3.35766527, 2.75677639, 1.68089917,
#        3.22604199, 3.14020072, 3.09441871, 2.83689491, 3.52362505,
#        2.05287799, 2.75677639, 3.14020072, 2.31612455, 2.76822189,
#        4.11879118, 3.05435945, 3.33477426, 2.5564801 , 2.075769  ])

# %%
plt.scatter(x,y)
plt.xlabel('cgpa')
plt.ylabel('package')
plt.plot(x_train,lr.predict(x_train), color='red')
plt.show()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
a=lr.coef_
a
# Out:
# array([0.57227512])

# %%
b = lr.intercept_
b
# Out:
# -1.0259621522745266

# %% [markdown]
# # simple linear regression by class and object

# %%
# class MeraLR:
    
#     def __init__(self):
#         self.m = None
#         self.b = None
        
#     def fit(self,X_train,y_train):
        
#         num = 0
#         den = 0
        
#         for i in range(X_train.shape[0]):
            
#             num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
#             den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        
#         self.m = num/den
#         self.b = y_train.mean() - (self.m * X_train.mean())
#         print(self.m)
#         print(self.b)       
    
#     def predict(self,X_test):
        
#         print(X_test)
        
#         return self.m * X_test + self.b

# %%
class mm:
    def __init__ (self):
        m=None
        b=None
    def fit(self,x_train,y_train):
        upper=0
        lower=0
        
        for i in range(x_train.shape[0]):
            upper = upper + ((y_train[i]-y_train.mean()) * (x_train[i] - x_train.mean()))
            lower = lower + ((x_train[i] - x_train.mean()) * (x_train[i] - x_train.mean()))
            
            self.m = upper/lower
            self.b = y_train.mean() - (self.m*(x_train.mean()))
            
            print(f"the coeficient is {self.m}")
            print(f"the intercepot_ is {self.b}")
                  
    def predict(self,x_test):
        
        print(x_test)
        
        return ((self.m * x_test) + (self.b))

# class mm:
#     def __init__(self):
#         self.m = None
#         self.b = None
    
#     def fit(self, x_train, y_train):
#         upper = 0
#         lower = 0
        
#         for i in range(x_train.shape[0]):
#             upper += (y_train[i] - y_train.mean()) * (x_train[i] - x_train.mean())
#             lower += (x_train[i] - x_train.mean()) * (x_train[i] - x_train.mean())
        
#         self.m = upper / lower
#         self.b = y_train.mean() - (self.m * x_train.mean())
        
#         print(f"The coefficient is {self.m}")
#         print(f"The intercept is {self.b}")
                  
#     def predict(self, x_test):
#         print(x_test)
#         return (self.m * x_test) + self.b

# %%
obj = mm()

# %%
obj.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ...

# %%
class MeraLR:
    
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit(self,X_train,y_train):
        
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        
        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)       
    
    def predict(self,X_test):
        
        print(X_test)
        
        return self.m * X_test + self.b

# %%
obj = MeraLR()

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 lr.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
# ...
