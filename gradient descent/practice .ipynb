# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("F:\Jupyter Notebook\python programe\DS  first\ML\placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]  # this place use the slicing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size = 0.25, random_state=1234)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (150, 1)
# (150,)
# (50, 1)
# (50,)

# %%
from sklearn.linear_model import LinearRegression 
l = LinearRegression()

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre = l.predict(x_test)
y_pre
# Out:
# array([3.10901127, 2.68098065, 3.62380484, 3.93036731, 4.23692978,
#        3.31145818, 3.5023367 , 2.84293818, 3.05695349, 3.42714213,
#        2.84872238, 2.90656436, 1.90589819, 2.62313868, 2.94705374,
#        2.97597473, 2.3570656 , 3.07430608, 2.90078016, 3.33459497,
#        3.06852189, 2.81980139, 3.62958904, 4.29477175, 3.50812089,
#        2.07363992, 3.74527299, 2.20089226, 3.17842164, 4.36418212,
#        2.83136979, 1.58198313, 2.5826493 , 2.31657621, 1.8885456 ,
#        2.13726609, 2.86607497, 3.14950065, 2.53637572, 2.94126954,
#        2.44961276, 2.96440633, 3.36930015, 2.76195942, 1.67453029,
#        3.23626361, 3.14950065, 3.10322707, 2.84293818, 3.53704188])

# %%
l.coef_
# Out:
# array([0.57841975])

# %%
l.intercept_
# Out:
# -1.0613951132829804

# %%
plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red')

# %%
y_pred = ((0.578 * x) + 2)

# %%
plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) + 1)


plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) + 0.5)


plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) + 0)


plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) + -0.5)


plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) + -1)


plt.scatter(x,y)
plt.plot(x,l.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %%
y_pred = ((0.578 * x) - 1.1)


plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b = 0')    # when b =100
plt.legend()
plt.show()

# %% [markdown]
# # gredient dicent using for loop

# %%
b = 1
m = 0.578
lr = 0.0001

epochs = 100


for i in range(epochs):
  loss_slope = -2 * np.sum(y_train - m*x_train['cgpa'].ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * x + b

  plt.plot(x,y_pred)

plt.scatter(x,y)

# %% [markdown]
# # multiple gredient dicent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.dropna(inplace=True) # Drop the Null
wine.reset_index(drop=True,
               inplace=True)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine = pd.read_csv("F:\Jupyter Notebook\python programe\DS  first\ML\winequality_red.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X=wine.drop('quality',axis=1)
Y=wine['quality']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,  # Input data
                                                    Y,  # output data
                                                    random_state=1234, # it select random samples
                                                    test_size=0.30)   #30 % test data hai means 70:30 ka ratio hai

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1119, 11)
# (1119,)
# (480, 11)
# (480,)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 642             9.9             0.540         0.45             2.3      0.071
# 678             8.3             0.780         0.10             2.6      0.081
# 412             7.1             0.735         0.16             1.9      0.100
# 73              8.3             0.675         0.26             2.1      0.084
# 985             7.4             0.580         0.00             2.0      0.064
# ...             ...               ...          ...             ...        ...
# 1228            5.1             0.420         0.00             1.8      0.044
# 1077            8.6             0.370         0.65             6.4      0.080
# 1318            7.5             0.630         0.27             2.0      0.083
# 723             7.1             0.310         0.30             2.2      0.053
# 815            10.8             0.450         0.33             2.5      0.099
#
# ...

# %%
y_train
# Out:
# 642     5
# 678     5
# 412     5
# 73      4
# 985     6
#        ..
# 1228    7
# 1077    5
# 1318    6
# 723     5
# 815     5
# Name: quality, Length: 1119, dtype: int64
